# %%
import numpy as np
import pandas as pd

# any tabular data is dataframe
# any column is series
# every row is also a series

# %%
stud_data = [
    [100, 60, 10],
    [90, 60, 7],
    [100, 100, 14],
    [80, 80, 1],
]

students = pd.DataFrame(stud_data,columns=['iq', 'marks', 'package'])

# %%
stud_dict_2 = {
    'iq': [100, 90, 120, 80],
    'marks': [10, 70, 20, 60],
    'package': [50, 80, 110, 20]
}

pd.DataFrame(stud_dict_2)
# Out:
#     iq  marks  package
# 0  100     10       50
# 1   90     70       80
# 2  120     20      110
# 3   80     60       20

# %%
ipl = pd.read_csv("C://users/dell/downloads/ipl-matches.csv")

# %%
# shape of the datasets
ipl.shape
# Out:
# (950, 20)

# %%
# dtypes
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
# index
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
# columns
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
# values
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
# head and tail
ipl.head()
ipl.tail()
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
# sample
ipl.sample()
# Out:
#          ID       City        Date Season MatchNumber             Team1  \
# 837  392237  Centurion  2009-05-22   2009  Semi Final  Delhi Daredevils
#
#                Team2            Venue       TossWinner TossDecision SuperOver  \
# 837  Deccan Chargers  SuperSport Park  Deccan Chargers        field         N
#
#          WinningTeam    WonBy  Margin method Player_of_Match  \
# 837  Deccan Chargers  Wickets     6.0    NaN    AC Gilchrist
#
#                                           Team1Players  \
# 837  ['G Gambhir', 'DA Warner', 'V Sehwag', 'TM Dil...
#
#                                           Team2Players      Umpire1    Umpire2
# 837  ['AC Gilchrist', 'HH Gibbs', 'AA Bilakhia', 'T...  BR Doctrove  DJ Harper

# %%
# info
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# is null
ipl.isnull()
# Out:
#         ID   City   Date  Season  MatchNumber  Team1  Team2  Venue  \
# 0    False  False  False   False        False  False  False  False
# 1    False  False  False   False        False  False  False  False
# 2    False  False  False   False        False  False  False  False
# 3    False  False  False   False        False  False  False  False
# 4    False  False  False   False        False  False  False  False
# ..     ...    ...    ...     ...          ...    ...    ...    ...
# 945  False  False  False   False        False  False  False  False
# 946  False  False  False   False        False  False  False  False
# 947  False  False  False   False        False  False  False  False
# 948  False  False  False   False        False  False  False  False
# 949  False  False  False   False        False  False  False  False
#
#      TossWinner  TossDecision  SuperOver  WinningTeam  WonBy  Margin  method  \
# 0         False         False      False        False  False   False    True
# ...

# %%
# describe
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
# duplicated
ipl.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Length: 950, dtype: bool

# %%
# rename to rename a column

ipl.rename(columns={'MatchNumber': 'Match No.'}, inplace=True)

# %%
ipl.head()
# Out:
#         ID       City        Date Season    Match No.  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
# math methods

# sum
print(students)
print("==================")
print(students.sum(axis=0))
print("==================")
print(students.sum(axis=1))
# Out:
#     iq  marks  package
# 0  100     60       10
# 1   90     60        7
# 2  100    100       14
# 3   80     80        1
# ...
# iq         370
# marks      300
# package     32
# dtype: int64
# ...
# 0    170
# 1    157
# 2    214
# 3    161
# dtype: int64

# %%
# mean
print(students.mean(axis=1))
print("===================")
# variance
print(students.var())
# Out:
# 0    56.666667
# 1    52.333333
# 2    71.333333
# 3    53.666667
# dtype: float64
# ...
# iq          91.666667
# marks      366.666667
# package     30.000000
# dtype: float64

# %%
# selecting single col from data frame
ipl['City']
# Out:
# 0       Ahmedabad
# 1       Ahmedabad
# 2         Kolkata
# 3         Kolkata
# 4          Mumbai
#           ...
# 945       Kolkata
# 946        Mumbai
# 947         Delhi
# 948    Chandigarh
# 949     Bangalore
# Name: City, Length: 950, dtype: object

# %%
# selecting single col from data frame
ipl[['City', 'Team1', 'Team2']]
# Out:
#            City                        Team1                        Team2
# 0     Ahmedabad             Rajasthan Royals               Gujarat Titans
# 1     Ahmedabad  Royal Challengers Bangalore             Rajasthan Royals
# 2       Kolkata  Royal Challengers Bangalore         Lucknow Super Giants
# 3       Kolkata             Rajasthan Royals               Gujarat Titans
# 4        Mumbai          Sunrisers Hyderabad                 Punjab Kings
# ..          ...                          ...                          ...
# 945     Kolkata        Kolkata Knight Riders              Deccan Chargers
# 946      Mumbai               Mumbai Indians  Royal Challengers Bangalore
# 947       Delhi             Delhi Daredevils             Rajasthan Royals
# 948  Chandigarh              Kings XI Punjab          Chennai Super Kings
# 949   Bangalore  Royal Challengers Bangalore        Kolkata Knight Riders
#
# [950 rows x 3 columns]

# %%
# selecting rows form dataframe

# selecting single
ipl.iloc[4]
# Out:
# ID                                                           1304116
# City                                                          Mumbai
# Date                                                      2022-05-22
# Season                                                          2022
# Match No.                                                         70
# Team1                                            Sunrisers Hyderabad
# Team2                                                   Punjab Kings
# Venue                                       Wankhede Stadium, Mumbai
# TossWinner                                       Sunrisers Hyderabad
# TossDecision                                                     bat
# SuperOver                                                          N
# WinningTeam                                             Punjab Kings
# WonBy                                                        Wickets
# Margin                                                           5.0
# ...

# %%
# selecting multiple rows
ipl[:5]
# Out:
#         ID       City        Date Season    Match No.  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
# fancy indexing
ipl.iloc[[0,4,15]]
# Out:
#          ID       City        Date Season Match No.                Team1  \
# 0   1312200  Ahmedabad  2022-05-29   2022     Final     Rajasthan Royals
# 4   1304116     Mumbai  2022-05-22   2022        70  Sunrisers Hyderabad
# 15  1304105     Mumbai  2022-05-12   2022        59  Chennai Super Kings
#
#              Team2                             Venue           TossWinner  \
# 0   Gujarat Titans  Narendra Modi Stadium, Ahmedabad     Rajasthan Royals
# 4     Punjab Kings          Wankhede Stadium, Mumbai  Sunrisers Hyderabad
# 15  Mumbai Indians          Wankhede Stadium, Mumbai       Mumbai Indians
#
#    TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0           bat         N  Gujarat Titans  Wickets     7.0    NaN
# 4           bat         N    Punjab Kings  Wickets     5.0    NaN
# 15        field         N  Mumbai Indians  Wickets     5.0    NaN
#
#    Player_of_Match                                       Team1Players  \
# ...

# %%
# selecting both rows and columns
ipl.iloc[0:3, 0:3]
# Out:
#         ID       City        Date
# 0  1312200  Ahmedabad  2022-05-29
# 1  1312199  Ahmedabad  2022-05-27
# 2  1312198    Kolkata  2022-05-25

# %%
ipl.loc[0:5,'City':'Team1']
# Out:
#         City        Date Season    Match No.                        Team1
# 0  Ahmedabad  2022-05-29   2022        Final             Rajasthan Royals
# 1  Ahmedabad  2022-05-27   2022  Qualifier 2  Royal Challengers Bangalore
# 2    Kolkata  2022-05-25   2022   Eliminator  Royal Challengers Bangalore
# 3    Kolkata  2022-05-24   2022  Qualifier 1             Rajasthan Royals
# 4     Mumbai  2022-05-22   2022           70          Sunrisers Hyderabad
# 5     Mumbai  2022-05-21   2022           69               Delhi Capitals

# %%
# to find all the final winners
mask = ipl['Match No.'] == 'Final'

new_df = ipl[mask]
print(new_df[['Season', 'WinningTeam']])

# ipl[ipl['MatchNumber'] == 'Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# how many super over finishes have occured
ipl[ipl['SuperOver'] == 'Y'].shape[0]

# shape[1] gives number of columns
# ipl[ipl['SuperOver'] == 'Y'].shape[1]
# Out:
# 14

# %%
# how many matches has csk won in kolkata

ipl[(ipl['WinningTeam'] == "Chennai Super Kings") & (ipl['City'] == 'Kolkata')].shape[0]
# Out:
# 5

# %%
# toss winner is match winner in percentage
ipl[(ipl['TossWinner']==ipl['WinningTeam'])].shape[0]/ipl.shape[0]*100
# Out:
# 51.473684210526315

# %%
# adding new columns
ipl['Country']='India'
ipl.head()
# Out:
#         ID       City        Date Season    Match No.  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
# ...

# %%
# form existing ones
movies.dropna(inplace=True)
